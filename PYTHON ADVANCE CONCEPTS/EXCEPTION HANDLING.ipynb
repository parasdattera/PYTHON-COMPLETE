# %%
''' ___________ Exception Handling __________

* exception is an event occurs during execution of a program which disrupts normal flow of program
* exception handling is process of responding to the occurrence of exceptions
* terms used while handling exceptions:
                    1. try - try block will have code that might have an exception
                    2. except - if exception is in try block then this block will execute
                    3. else - if no exceptions in try block this will be executed after try block
                    4. finally - this block will be executed whether try has exception or not

* raising an exception  -- using "raise Exception" keyword -- used when as a coder you know that in a specific block there
                    might be an exception that can occur

                    raise Exception('there is an exception in program!!')

* instead of using try except block we can use "assert" keyword (it will stop execution of program if exception occur)
                    so thats why it should be in try block 
                    
                    assert (code),"msg if exception"

* using try and except keyword with python built in exception handling keywords
                    such as SyntaxError -- if syntax error in code
                            IndentationError -- if there is an indextation error in code
                            NameError -- if variable not found
                            TypeError -- when there is an inappropriate type of variable
                            more sample are -- ValueError,ZeroDivisionError,IndexError,KeyError,FileNotFoundError
                                                ,IOError,AttributeError,ImportError,ModuleNotFoundError,ArithmeticError
                                                ,MemoryError,RuntimeError,Exception(base class for all exceptions)


'''

# sample -- how exceptions can occur
#print(0/0)

# raise an exception 

# x =10
# if x>5:
#     raise Exception('x should not exceed 5. The value of x was: {}'.format(x))

# sample -- AssertionError -- keyword -- assert 

# x = 10
# assert x==1, "x is not equal to 1"


# sample -- try except block

# import sys
# def linux_interaction():
#     assert('linux' in sys.platform),'function can only run on linux system'

# try:
#     linux_interaction()
# except:
#     print('linux function was not executed')

# # if exception is handled using except keyword then program will executed completely
# print("hello world")


# sample -- try except (multiple types of exception provided by python) -- if using multiple types of exce


# import sys
# def linux_interaction():
#     assert('linux' in sys.platform),'function can only run on linux system'
#     print("do something")
# try:
#     linux_interaction()
# except Exception as error:
#     print(error)
#     print("hello")



# sample -- try except else finally 

try:
    x=10
    y=10
    z=x/y
    print(z)
except ArithmeticError as e:
    print(e)
else:
    z=10
    print(z)
finally:
    print("hello world")
# Out:
# 1.0
# 10
# hello world
